# %% [markdown]
# Data from [MTA](http://web.mta.info/developers/turnstile.html)
# Description [here](http://web.mta.info/developers/resources/nyct/turnstile/ts_Field_Description.txt)
#
# This is just a starting attempt to play around with the data. I'm only looking at the week of May 4th 2019 and Abishek and Max are looking at the two subsequent weeks.
#
# High # of entries *per turnstile*.
#
# [GitHub](https://github.com/huge-reality/MTA_Project_Group_5)
#
# __Action item__: Filter based on times

# %% [markdown]
# Brainstorming ways to approach manipulating the data:
# - only look at the 8AM - 12PM and 4PM - 8PM blocks

# %%
import pandas as pd
import numpy as np
import matplotlib
pd.set_option('display.float_format', lambda x: '%.1f' % x)

# %%
df = pd.read_csv('turnstile_190504.txt')
df.tail(30)
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 206827  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  04/29/2019
# 206828  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  04/29/2019
# 206829  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  04/29/2019
# 206830  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  04/29/2019
# 206831  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  04/29/2019
# 206832  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  04/29/2019
# 206833  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  04/30/2019
# 206834  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  04/30/2019
# 206835  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  04/30/2019
# 206836  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  04/30/2019
# 206837  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  04/30/2019
# 206838  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  04/30/2019
# 206839  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/01/2019
# 206840  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/01/2019
# 206841  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/01/2019
# 206842  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/01/2019
# 206843  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/01/2019
# 206844  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/01/2019
# 206845  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/02/2019
# 206846  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/02/2019
# 206847  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/02/2019
# 206848  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/02/2019
# 206849  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/02/2019
# 206850  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/02/2019
# 206851  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/03/2019
# 206852  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/03/2019
# 206853  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/03/2019
# 206854  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/03/2019
# 206855  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/03/2019
# 206856  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/03/2019
#
#             TIME     DESC  ENTRIES  \
# 206827  01:00:00  REGULAR     5554
# 206828  05:00:00  REGULAR     5554
# 206829  09:00:00  REGULAR     5554
# 206830  13:00:00  REGULAR     5554
# 206831  17:00:00  REGULAR     5554
# 206832  21:00:00  REGULAR     5554
# 206833  01:00:00  REGULAR     5554
# 206834  05:00:00  REGULAR     5554
# 206835  09:00:00  REGULAR     5554
# 206836  13:00:00  REGULAR     5554
# 206837  17:00:00  REGULAR     5554
# 206838  21:00:00  REGULAR     5554
# 206839  01:00:00  REGULAR     5554
# 206840  05:00:00  REGULAR     5554
# 206841  09:00:00  REGULAR     5554
# 206842  13:00:00  REGULAR     5554
# 206843  17:00:00  REGULAR     5554
# 206844  21:00:00  REGULAR     5554
# 206845  01:00:00  REGULAR     5554
# 206846  05:00:00  REGULAR     5554
# 206847  09:00:00  REGULAR     5554
# 206848  13:00:00  REGULAR     5554
# 206849  17:00:00  REGULAR     5554
# 206850  21:00:00  REGULAR     5554
# 206851  01:00:00  REGULAR     5554
# 206852  05:00:00  REGULAR     5554
# 206853  09:00:00  REGULAR     5554
# 206854  13:00:00  REGULAR     5554
# 206855  17:00:00  REGULAR     5554
# 206856  21:00:00  REGULAR     5554
#
#         EXITS
# 206827                                                376
# 206828                                                376
# 206829                                                376
# 206830                                                376
# 206831                                                376
# 206832                                                376
# 206833                                                376
# 206834                                                376
# 206835                                                376
# 206836                                                376
# 206837                                                376
# 206838                                                376
# 206839                                                376
# 206840                                                376
# 206841                                                376
# 206842                                                376
# 206843                                                376
# 206844                                                376
# 206845                                                376
# 206846                                                376
# 206847                                                376
# 206848                                                376
# 206849                                                376
# 206850                                                376
# 206851                                                376
# 206852                                                376
# 206853                                                376
# 206854                                                376
# 206855                                                376
# 206856                                                376

# %%
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206857 entries, 0 to 206856
# Data columns (total 11 columns):
# C/A                                                                     206857 non-null object
# UNIT                                                                    206857 non-null object
# SCP                                                                     206857 non-null object
# STATION                                                                 206857 non-null object
# LINENAME                                                                206857 non-null object
# DIVISION                                                                206857 non-null object
# DATE                                                                    206857 non-null object
# TIME                                                                    206857 non-null object
# DESC                                                                    206857 non-null object
# ENTRIES                                                                 206857 non-null int64
# EXITS                                                                   206857 non-null int64
# dtypes: int64(2), object(9)
# memory usage: 17.4+ MB

# %% [markdown]
# First info: no null values

# %%
df['UNIT']
# Out:
# 0         R051
# 1         R051
# 2         R051
# 3         R051
# 4         R051
#           ...
# 206852    R469
# 206853    R469
# 206854    R469
# 206855    R469
# 206856    R469
# Name: UNIT, Length: 206857, dtype: object

# %%
df.rename(columns = {'EXITS                                                               ':'EXITS'}, inplace = True)

# %%
df.head(119)
# Out:
#       C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0    A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  00:00:00
# 1    A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  04:00:00
# 2    A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  08:00:00
# 3    A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  12:00:00
# 4    A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  16:00:00
# ..    ...   ...       ...     ...      ...      ...         ...       ...
# 114  A002  R051  02-03-00   59 ST  NQR456W      BMT  05/01/2019  08:00:00
# 115  A002  R051  02-03-00   59 ST  NQR456W      BMT  05/01/2019  12:00:00
# 116  A002  R051  02-03-00   59 ST  NQR456W      BMT  05/01/2019  16:00:00
# 117  A002  R051  02-03-00   59 ST  NQR456W      BMT  05/01/2019  20:00:00
# 118  A002  R051  02-03-00   59 ST  NQR456W      BMT  05/02/2019  00:00:00
#
#         DESC  ENTRIES    EXITS
# 0    REGULAR  7035249  2384833
# 1    REGULAR  7035269  2384840
# 2    REGULAR  7035292  2384875
# 3    REGULAR  7035392  2384951
# 4    REGULAR  7035651  2385020
# ..       ...      ...      ...
# 114  REGULAR  1226009  4609409
# 115  REGULAR  1226067  4610091
# 116  REGULAR  1226156  4610489
# 117  REGULAR  1226417  4611104
# 118  REGULAR  1226487  4611272
#
# [119 rows x 11 columns]

# %%
df.describe()
# Out:
#            ENTRIES        EXITS
# count     206857.0     206857.0
# mean    40575302.0   33197992.8
# std    208275164.4  192669891.6
# min            0.0          0.0
# 25%       349546.0     141334.0
# 50%      2176408.0    1241604.0
# 75%      6775342.0    4590174.0
# max   2129342740.0 2124126951.0

# %%
print('Unique value counts:')
print('SCP', df.SCP.nunique())
print('UNIT', df.UNIT.nunique())
print('C/A', df['C/A'].nunique())
print('STATION', df.STATION.nunique())
# Out:
# Unique value counts:
# SCP 220
# UNIT 467
# C/A 743
# STATION 377

# %%
df['entry_count'] = df['ENTRIES'].diff()
df['exit_count'] = df['EXITS'].diff()

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  16:00:00
#
#       DESC  ENTRIES    EXITS  entry_count  exit_count
# 0  REGULAR  7035249  2384833          nan         nan
# 1  REGULAR  7035269  2384840         20.0         7.0
# 2  REGULAR  7035292  2384875         23.0        35.0
# 3  REGULAR  7035392  2384951        100.0        76.0
# 4  REGULAR  7035651  2385020        259.0        69.0

# %%
df.describe()
# Out:
#            ENTRIES        EXITS   entry_count    exit_count
# count     206857.0     206857.0      206856.0      206856.0
# mean    40575302.0   33197992.8         -34.0         -11.5
# std    208275164.4  192669891.6    44082744.0    40678076.7
# min            0.0          0.0 -2116018673.0 -2111174859.0
# 25%       349546.0     141334.0           9.0           7.0
# 50%      2176408.0    1241604.0          72.0          52.0
# 75%      6775342.0    4590174.0         245.0         171.0
# max   2129342740.0 2124126951.0  2121120457.0  2118903676.0

# %%
df = pd.read_csv('turnstile_190504.txt')
df.rename(columns = {'EXITS                                                               ':'EXITS'}, inplace = True)
# df['entry_count'] = df['ENTRIES'].diff()
# df['exit_count'] = df['EXITS'].diff()

# df.entry_count = df.entry_count.clip(lower = 0)
# df.exit_count = df.exit_count.clip(lower = 0)
# df.entry_count = df.entry_count.clip(upper = 2000)
# df.exit_count = df.exit_count.clip(lower = 0)

# %%
df.describe()
# Out:
#            ENTRIES        EXITS
# count     206857.0     206857.0
# mean    40575302.0   33197992.8
# std    208275164.4  192669891.6
# min            0.0          0.0
# 25%       349546.0     141334.0
# 50%      2176408.0    1241604.0
# 75%      6775342.0    4590174.0
# max   2129342740.0 2124126951.0

# %%
# df.entry_count.plot.hist(bins=50, grid=False, figsize=(12,8), color='#86bf91', zorder=2, rwidth=0.9)

# %%
df = pd.read_csv('turnstile_190504.txt')
df.rename(columns = {'EXITS                                                               ':'EXITS'}, inplace = True)

# df['entry_count'] = 0
df['entry_count'] = df['ENTRIES'].diff()


# df.groupby(['SCP']) == 0

df.head()

# for row in df.groupby(['SCP']):
#    print(row)

# def check(a):
#    if a < 0:
#        a = 0

# df.groupby('SCP')['entry_count'].transform(check)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/27/2019  16:00:00
#
#       DESC  ENTRIES    EXITS  entry_count
# 0  REGULAR  7035249  2384833          nan
# 1  REGULAR  7035269  2384840         20.0
# 2  REGULAR  7035292  2384875         23.0
# 3  REGULAR  7035392  2384951        100.0
# 4  REGULAR  7035651  2385020        259.0

# %%
df.describe()
# Out:
#            ENTRIES        EXITS   entry_count
# count     206857.0     206857.0      206856.0
# mean    40575302.0   33197992.8         -34.0
# std    208275164.4  192669891.6    44082744.0
# min            0.0          0.0 -2116018673.0
# 25%       349546.0     141334.0           9.0
# 50%      2176408.0    1241604.0          72.0
# 75%      6775342.0    4590174.0         245.0
# max   2129342740.0 2124126951.0  2121120457.0

# %%
def zoey(a):
    a = 1
    
s = df.groupby(['SCP']).entry_count.sum()
print(type(s))
print(s)
# Out:
# <class 'pandas.core.series.Series'>
# SCP
# 00-00-00    1853103751.0
# 00-00-01    1382061716.0
# 00-00-02    2213271538.0
# 00-00-03   -4662380349.0
# 00-00-04    3336043671.0
#                 ...
# 05-03-06     -10104718.0
# 05-05-00      33554853.0
# 05-05-01     -33554853.0
# 05-06-00       4098737.0
# 05-06-01      -3458358.0
# Name: entry_count, Length: 220, dtype: float64

# %%
df = pd.read_csv('turnstile_190504.txt')
df.rename(columns = {'EXITS                                                               ':'EXITS'}, inplace = True)
# df3 = df[df.TIME == '12:00:00']

# df['DATETIME'] = df['DATE'] + ' ' + df['TIME']
df['DATE'] = pd.to_datetime(df['TIME'], format= "%H:%M:%S")
# df.drop(columns=['DATE', 'TIME'], inplace=True)

df.info()
print(df.describe())
print(df.head())

print('\n\n\n\n')


index0 = df[(df['TIME'] == '00:00:00')].index 
df = df.drop(index0)
index4 = df[(df['TIME'] == '04:00:00')].index 
df = df.drop(index4)
index16 = df[(df['TIME'] == '16:00:00')].index 
df = df.drop(index16)
index20 = df[(df['TIME'] == '20:00:00')].index 
df = df.drop(index20)
df.info()
df.describe()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206857 entries, 0 to 206856
# Data columns (total 11 columns):
# C/A         206857 non-null object
# UNIT        206857 non-null object
# SCP         206857 non-null object
# STATION     206857 non-null object
# LINENAME    206857 non-null object
# DIVISION    206857 non-null object
# DATE        206857 non-null datetime64[ns]
# TIME        206857 non-null object
# DESC        206857 non-null object
# ENTRIES     206857 non-null int64
# EXITS       206857 non-null int64
# dtypes: datetime64[ns](1), int64(2), object(8)
# memory usage: 17.4+ MB
#            ENTRIES        EXITS
# count     206857.0     206857.0
# mean    40575302.0   33197992.8
# std    208275164.4  192669891.6
# min            0.0          0.0
# 25%       349546.0     141334.0
# 50%      2176408.0    1241604.0
# 75%      6775342.0    4590174.0
# max   2129342740.0 2124126951.0
#     C/A  UNIT       SCP STATION LINENAME DIVISION                DATE  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT 1900-01-01 00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT 1900-01-01 04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT 1900-01-01 08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT 1900-01-01 12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT 1900-01-01 16:00:00
#
#        TIME     DESC  ENTRIES    EXITS
# 0  00:00:00  REGULAR  7035249  2384833
# 1  04:00:00  REGULAR  7035269  2384840
# 2  08:00:00  REGULAR  7035292  2384875
# 3  12:00:00  REGULAR  7035392  2384951
# 4  16:00:00  REGULAR  7035651  2385020
#
#
#
#
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137839 entries, 2 to 206856
# Data columns (total 11 columns):
# C/A         137839 non-null object
# UNIT        137839 non-null object
# SCP         137839 non-null object
# STATION     137839 non-null object
# LINENAME    137839 non-null object
# DIVISION    137839 non-null object
# DATE        137839 non-null datetime64[ns]
# TIME        137839 non-null object
# DESC        137839 non-null object
# ENTRIES     137839 non-null int64
# EXITS       137839 non-null int64
# dtypes: datetime64[ns](1), int64(2), object(8)
# memory usage: 12.6+ MB
#      C/A  UNIT       SCP STATION LINENAME DIVISION                DATE  \
# 2   A002  R051  02-00-00   59 ST  NQR456W      BMT 1900-01-01 08:00:00
# 3   A002  R051  02-00-00   59 ST  NQR456W      BMT 1900-01-01 12:00:00
# 8   A002  R051  02-00-00   59 ST  NQR456W      BMT 1900-01-01 08:00:00
# 9   A002  R051  02-00-00   59 ST  NQR456W      BMT 1900-01-01 12:00:00
# 14  A002  R051  02-00-00   59 ST  NQR456W      BMT 1900-01-01 08:00:00
#
#         TIME     DESC  ENTRIES    EXITS
# 2   08:00:00  REGULAR  7035292  2384875
# 3   12:00:00  REGULAR  7035392  2384951
# 8   08:00:00  REGULAR  7036125  2385103
# 9   12:00:00  REGULAR  7036197  2385155
# 14  08:00:00  REGULAR  7036789  2385385

# %%
df['entry_count'] = df['ENTRIES'].diff()
df.describe()
# Out:
#            ENTRIES        EXITS   entry_count
# count     137839.0     137839.0      137838.0
# mean    35989825.1   29094562.6         -51.0
# std    192406027.4  178317112.7    54002114.1
# min            0.0          0.0 -2116018673.0
# 25%       227137.5      99366.0           8.0
# 50%      1718141.0    1024323.0          91.0
# 75%      6072619.5    3885787.5         323.0
# max   2129342740.0 2124126951.0  2121120457.0
